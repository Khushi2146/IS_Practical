# %%
import socket
import platform
import requests
from datetime import datetime

# Practical header
print("="*70)
print("CYBER SECURITY ENVIRNMENT SETUP USING GOOGLE COLAB")
print("=" * 70)

# Date and Time information
print("\nCURRENT DATE AND TIME ")
print("-"*70)
current_time = datetime.now()
print("Current Date and Time :",current_time)

# System Information
print("\nSYSTEM INFORMATION")
print("-"*70)
print("Operating System :",platform.system())
print("System Release :",platform.release())
print("System Version  :", platform.version())
print("Machine Type  :", platform.machine())
print("Processor :", platform.processor())

#Host Information
print("\nHOST INFORMATION")
print("-"*70)
hostname=socket.gethostname()
print("Host name :",hostname)

try:
  ip_address = socket.gethostbyname(hostname)
  print("IP Address : ",ip_address)
except:
  print("Unable to retrive IP Address")


#Internet connectivity test

print("\nINTERNET CONNECTIVITY TEST")
print("-" * 70)
try:
  response = requests.get("https://www.google.com")
  print("Connection Status : SUCCESS")
  print("HTTP Status Code  :", response.status_code)
except:
  print("Connection Status : FAILED")

# DNS RESOLUTION TEST

print("\nDNS RESOLUTION TEST")
print("-" * 70)
try:
  google_ip = socket.gethostbyname("www.google.com")
  print("Domain Name : www.google.com")
  print("Resolved IP :", google_ip)
except:
  print("DNS Resolution Failed")

#Port connectivity test

print("\nPORT CONNECTIVITY TEST")
print("-" * 70)
host = "google.com"
ports = [80, 443]
for port in ports:
  try:
    connection = socket.create_connection((host, port), timeout=5)
    print(f"Port {port} : OPEN")
    connection.close()
  except:
    print(f"Port {port} : CLOSED")

# Internet connectivity test

print("\nINTERNET CONNECTIVITY TEST")
print("-" * 70)
try:
  response = requests.get("https://www.google.com")
  print("Connection Status : SUCCESS")
  print("HTTP Status Code  :", response.status_code)
except:
  print("Connection Status : FAILED")


# DNS Resolution Test

print("\nDNS RESOLUTION TEST")
print("-" * 70)
try:
  google_ip = socket.gethostbyname("www.google.com")
  print("Domain Name : www.google.com")
  print("Resolved IP :", google_ip)
except:
  print("DNS Resolution Failed")


#Port Connectivity Test

print("\nPORT CONNECTIVITY TEST")
print("-" * 70)
host = "google.com"
ports = [80, 443]
for port in ports:
  try:
    connection = socket.create_connection((host, port), timeout=5)
    print(f"Port {port} : OPEN")
    connection.close()
  except:
    print(f"Port {port} : CLOSED")

# Website Security Test

print("\nWEBSITE SECURITY CHECK")
print("-" * 70)
url = "https://www.google.com"
if url.startswith("https://"):
  print("Secure HTTPS Protocol Detected")
else:
  print("Insecure Protocol")


# CyberSecurity Envirnment status

print("\nCYBERSECURITY ENVIRONMENT STATUS")
print("-" * 70)
print("✓ Python Environment Ready")
print("✓ Internet Connectivity Verified")
print("✓ DNS Resolution Working")
print("✓ Port Connectivity Verified")
print("✓ HTTPS Security Verified")
print("✓ Security Environment Ready")
print("\nPractical Completed Successfully")
print("=" * 70)
# Out:
# ...
# CYBER SECURITY ENVIRNMENT SETUP USING GOOGLE COLAB
# ...
#
# CURRENT DATE AND TIME
# ----------------------------------------------------------------------
# Current Date and Time : 2026-07-14 12:24:34.930321
#
# SYSTEM INFORMATION
# ----------------------------------------------------------------------
# Operating System : Linux
# System Release : 6.6.122+
# System Version  : #1 SMP Thu Apr 30 18:17:14 UTC 2026
# Machine Type  : x86_64
# Processor : x86_64
#
# HOST INFORMATION
# ----------------------------------------------------------------------
# Host name : e85702d1fed4
# IP Address :  172.28.0.12
#
# INTERNET CONNECTIVITY TEST
# ----------------------------------------------------------------------
# Connection Status : SUCCESS
# HTTP Status Code  : 200
#
# DNS RESOLUTION TEST
# ----------------------------------------------------------------------
# Domain Name : www.google.com
# Resolved IP : 142.251.151.119
#
# PORT CONNECTIVITY TEST
# ...
